# %% [markdown]
# Installing some dependencies

# %%
# !pip install bitsandbytes accelerate transformers-interpret shap inseq
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.7.0)
# Collecting transformers-interpret
#   Downloading transformers_interpret-0.10.0-py3-none-any.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: shap in /usr/local/lib/python3.11/dist-packages (0.47.2)
# Collecting inseq
#   Downloading inseq-0.6.0-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: torch<3,>=2.2 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.32.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.3)
# Collecting captum>=0.3.1 (from transformers-interpret)
#   Downloading captum-0.8.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: ipython<8.0.0,>=7.31.1 in /usr/local/lib/python3.11/dist-packages (from transformers-interpret) (7.34.0)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from transformers-interpret) (4.52.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from shap) (1.15.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.11/dist-packages (from shap) (4.67.1)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.11/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.11/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from shap) (3.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from shap) (4.14.0)
# Requirement already satisfied: rich>=10.13.0 in /usr/local/lib/python3.11/dist-packages (from inseq) (13.9.4)
# Requirement already satisfied: protobuf>=3.20.1 in /usr/local/lib/python3.11/dist-packages (from inseq) (5.29.5)
# Collecting jaxtyping>=0.2.25 (from inseq)
#   Downloading jaxtyping-0.3.2-py3-none-any.whl.metadata (7.0 kB)
# Collecting typeguard<=2.13.3 (from inseq)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: matplotlib>=3.5.3 in /usr/local/lib/python3.11/dist-packages (from inseq) (3.10.0)
# Collecting numpy>=1.17 (from bitsandbytes)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2025.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (1.1.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (75.2.0)
# Collecting jedi>=0.16 (from ipython<8.0.0,>=7.31.1->transformers-interpret)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (4.9.0)
# Collecting wadler-lindig>=0.1.3 (from jaxtyping>=0.2.25->inseq)
#   Downloading wadler_lindig-0.1.6-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.13.0->inseq) (3.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.2->bitsandbytes) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->transformers-interpret) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->transformers-interpret) (0.21.1)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.11/dist-packages (from transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (0.2.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (3.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython<8.0.0,>=7.31.1->transformers-interpret) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.13.0->inseq) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython<8.0.0,>=7.31.1->transformers-interpret) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0.0,>=7.31.1->transformers-interpret) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.3->inseq) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.2->bitsandbytes) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2025.4.26)
# Downloading bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 14.3 MB/s eta 0:00:00
# Downloading transformers_interpret-0.10.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 3.8 MB/s eta 0:00:00
# Downloading inseq-0.6.0-py3-none-any.whl (186 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.6/186.6 kB 18.4 MB/s eta 0:00:00
# Downloading captum-0.8.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 77.9 MB/s eta 0:00:00
# Downloading jaxtyping-0.3.2-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 5.7 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 113.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 120.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 96.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 17.1 MB/s eta 0:00:00
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 25.3 MB/s eta 0:00:00
# Downloading wadler_lindig-0.1.6-py3-none-any.whl (20 kB)
# Installing collected packages: wadler-lindig, typeguard, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, jedi, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jaxtyping, nvidia-cusolver-cu12, captum, bitsandbytes, transformers-interpret, inseq
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.4.2
#     Uninstalling typeguard-4.4.2:
#       Successfully uninstalled typeguard-4.4.2
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# inflect 7.5.0 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed bitsandbytes-0.46.0 captum-0.8.0 inseq-0.6.0 jaxtyping-0.3.2 jedi-0.19.2 numpy-1.26.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 transformers-interpret-0.10.0 typeguard-2.13.3 wadler-lindig-0.1.6

# %% [markdown]
# # Explainability
#
#
# **Feature attribution methods** leverage the internal information (e.g. gradients, attention) or predictions of a model to quantify the relationship between its inputs and its predictions.
#
# Attribution methods produce **importance scores** (or *saliency scores*) for every element of the input, reflecting the importance of every input element in driving the model prediction. These scores are often presented using <span style="background:#A85E9E">highlights</span> (or *attribution maps*) to facilitate comprehension, although recent research showed the risks of textual highlights misinterpretation caused by human cognitive biases ([Jacovi et al. 2022](https://dl.acm.org/doi/abs/10.1145/3531146.3533127), [Jacovi et al. 2023](https://arxiv.org/abs/2305.02679))
#
# We can categorize feature attribution approaches in three major families:
# - **Gradient-based methods** such as [Gradients]() and [Integrated gradients]() use gradients as a natural source of information to motivate model predictions. Gradients for model parameters computed in relation to a loss function are commonly used during training to update model parameters, since they represent *the magnitude of change needed for a parameter such that the prediction matches the target label*. In the case of feature attribution, gradients computed with respect to a model prediction logit or probability are instead taken as *how much the parameter is contributing towards the prediction*.
#
# - **Surrogates models based on perturbation methods** such as [Occlusion](https://captum.ai/api/occlusion.html), [SHAP]() or [LIME]() estimate importance of inputs by introducing noise in the prediction process, usually by masking or removing either input features or network components, and verifying the downstream effect on model predictions. Intuitively, these can also be used to determine the importance of layers in the neural network.
#
# - **Internals-based methods** use quantities computed naturally by the network during their predictions to motivate its internal computations. For Transformers-based model, [attention weights](https://aclanthology.org/D19-1002/) are commonly used, by themselves or multiplied with other quantities, as indications of feature importance.
#
#
# **Note that:**
# - We distinguish gradient and internals methods since gradient methods require a *prediction target* (e.g. the predicted class label, the next generated word) to compute importance scores, while internals-based one generally do not rely on the predicted output to determine importance.

# %% [markdown]
# # Explainability in representative transformers models

# %% [markdown]
# ## Sentiment explainer (gradient-based approach)

# %%
# !pip install -U captum
# Out:
# Requirement already satisfied: captum in /usr/local/lib/python3.11/dist-packages (0.8.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from captum) (3.10.0)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.11/dist-packages (from captum) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from captum) (24.2)
# Requirement already satisfied: torch>=1.10 in /usr/local/lib/python3.11/dist-packages (from captum) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from captum) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.10->captum) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->captum) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.10->captum) (3.0.2)

# %%
pip install --force-reinstall numpy==1.26.4
# Out:
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
pip install --upgrade inseq
# Out:
# Requirement already satisfied: inseq in /usr/local/lib/python3.11/dist-packages (0.6.0)
# Requirement already satisfied: rich>=10.13.0 in /usr/local/lib/python3.11/dist-packages (from inseq) (13.9.4)
# Requirement already satisfied: transformers>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (4.52.4)
# Requirement already satisfied: protobuf>=3.20.1 in /usr/local/lib/python3.11/dist-packages (from inseq) (5.29.5)
# Requirement already satisfied: captum>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from inseq) (0.8.0)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from inseq) (1.26.4)
# Requirement already satisfied: jaxtyping>=0.2.25 in /usr/local/lib/python3.11/dist-packages (from inseq) (0.3.2)
# Requirement already satisfied: typeguard<=2.13.3 in /usr/local/lib/python3.11/dist-packages (from inseq) (2.13.3)
# Requirement already satisfied: torch>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from inseq) (2.6.0+cu124)
# Requirement already satisfied: matplotlib>=3.5.3 in /usr/local/lib/python3.11/dist-packages (from inseq) (3.10.0)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from inseq) (4.67.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from captum>=0.7.0->inseq) (24.2)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from jaxtyping>=0.2.25->inseq) (0.1.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.13.0->inseq) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.13.0->inseq) (2.19.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.1.1->inseq) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (0.32.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (0.5.3)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.11/dist-packages (from transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (0.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (1.1.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.13.0->inseq) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.3->inseq) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.1.1->inseq) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (2025.4.26)

# %%
pip install --upgrade transformers transformers-interpret captum
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.4)
# Requirement already satisfied: transformers-interpret in /usr/local/lib/python3.11/dist-packages (0.10.0)
# Requirement already satisfied: captum in /usr/local/lib/python3.11/dist-packages (0.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.32.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: ipython<8.0.0,>=7.31.1 in /usr/local/lib/python3.11/dist-packages (from transformers-interpret) (7.34.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from captum) (3.10.0)
# Requirement already satisfied: torch>=1.10 in /usr/local/lib/python3.11/dist-packages (from captum) (2.6.0+cu124)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (4.9.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.10->captum) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython<8.0.0,>=7.31.1->transformers-interpret) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython<8.0.0,>=7.31.1->transformers-interpret) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0.0,>=7.31.1->transformers-interpret) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->captum) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.10->captum) (3.0.2)

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer
model_name = "distilbert-base-uncased-finetuned-sst-2-english"
model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# With both the model and tokenizer initialized we are now able to get explanations on an example text.

from transformers_interpret import SequenceClassificationExplainer

cls_explainer = SequenceClassificationExplainer(
    model,
    tokenizer,
)
word_attributions = cls_explainer("I love you, I like you")
word_attributions
# Out:
# [('[CLS]', 0.0),
#  ('i', 0.2778543531894684),
#  ('love', 0.7792373299598694),
#  ('you', 0.3856005072593689),
#  (',', -0.017697645351290703),
#  ('i', 0.1207190603017807),
#  ('like', 0.1909111738204956),
#  ('you', 0.3399486243724823),
#  ('[SEP]', 0.0)]

# %% [markdown]
# Positive attribution numbers indicate a word contributes positively towards the predicted class, while negative numbers indicate a word contributes negatively towards the predicted class. Here we can see that I love you gets the most attention.

# %%
print(f'Predicted label {cls_explainer.predicted_class_index} aka {cls_explainer.predicted_class_name} label')
# Out:
# Predicted label 1 aka POSITIVE label

# %%
_ = cls_explainer.visualize()
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>POSITIVE (1.00)</b></text></td><td><text style="padding-right:2em"><b>POSITIVE</b></text></td><td><text style="padding-right:2em"><b>2.08</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 87%); opacity:1.0;                     line-height:1.75"><font color="black"> i                    </font></mark><mark style="background-color: hsl(120, 75%, 62%); opacity:1.0;                     line-height:1.75"><font color="black"> love                    </font></mark><mark style="background-color: hsl(120, 75%, 81%); opacity:1.0;                     line-height:1.75"><font color="black"> you                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ,                    </font></mark><mark style="background-color: hsl(120, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> i                    </font></mark><mark style="background-color: hsl(120, 75%, 91%); opacity:1.0;                     line-height:1.75"><font color="black"> like                    </font></mark><mark style="background-color: hsl(120, 75%, 84%); opacity:1.0;                     line-height:1.75"><font color="black"> you                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [SEP]                    </font></mark></td><tr></table>

# %% [markdown]
# Let's try with something more complicated:

# %%
word_attributions = cls_explainer("Your presence illuminates the room, drawing in positivity and fostering a sense of comfort for those around you")
print(f'Predicted label {cls_explainer.predicted_class_index} aka {cls_explainer.predicted_class_name} label')
_ = cls_explainer.visualize()
# Out:
# Predicted label 1 aka POSITIVE label
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>POSITIVE (1.00)</b></text></td><td><text style="padding-right:2em"><b>POSITIVE</b></text></td><td><text style="padding-right:2em"><b>2.89</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> your                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> presence                    </font></mark><mark style="background-color: hsl(0, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> ill                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> ##umi                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> ##nate                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##s                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> room                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> ,                    </font></mark><mark style="background-color: hsl(120, 75%, 91%); opacity:1.0;                     line-height:1.75"><font color="black"> drawing                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> in                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> po                    </font></mark><mark style="background-color: hsl(0, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##sit                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ivity                    </font></mark><mark style="background-color: hsl(120, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> and                    </font></mark><mark style="background-color: hsl(120, 75%, 71%); opacity:1.0;                     line-height:1.75"><font color="black"> foster                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ing                    </font></mark><mark style="background-color: hsl(120, 75%, 89%); opacity:1.0;        ...

# %%
word_attributions = cls_explainer("Your lack of consideration for others' perspectives often creates unnecessary tension and limits constructive discussions.")
print(f'Predicted label {cls_explainer.predicted_class_index} aka {cls_explainer.predicted_class_name} label')
_ = cls_explainer.visualize()
# Out:
# Predicted label 0 aka NEGATIVE label
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>NEGATIVE (1.00)</b></text></td><td><text style="padding-right:2em"><b>NEGATIVE</b></text></td><td><text style="padding-right:2em"><b>2.90</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> your                    </font></mark><mark style="background-color: hsl(120, 75%, 66%); opacity:1.0;                     line-height:1.75"><font color="black"> lack                    </font></mark><mark style="background-color: hsl(120, 75%, 85%); opacity:1.0;                     line-height:1.75"><font color="black"> of                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> consideration                    </font></mark><mark style="background-color: hsl(120, 75%, 87%); opacity:1.0;                     line-height:1.75"><font color="black"> for                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> others                    </font></mark><mark style="background-color: hsl(120, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> '                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> perspectives                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> often                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> creates                    </font></mark><mark style="background-color: hsl(120, 75%, 79%); opacity:1.0;                     line-height:1.75"><font color="black"> unnecessary                    </font></mark><mark style="background-color: hsl(120, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> tension                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> and                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> limits                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> constructive                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> discussions                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> .                    </font></mark><mark style="background-color: hs ...

# %%
word_attributions = cls_explainer("I hate you")
print(f'Predicted label {cls_explainer.predicted_class_index} aka {cls_explainer.predicted_class_name} label')
_ = cls_explainer.visualize()
# Out:
# Predicted label 0 aka NEGATIVE label
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>NEGATIVE (1.00)</b></text></td><td><text style="padding-right:2em"><b>NEGATIVE</b></text></td><td><text style="padding-right:2em"><b>0.85</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> i                    </font></mark><mark style="background-color: hsl(120, 75%, 51%); opacity:1.0;                     line-height:1.75"><font color="black"> hate                    </font></mark><mark style="background-color: hsl(0, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> you                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [SEP]                    </font></mark></td><tr></table>

# %% [markdown]
# ### Explaining Attributions for Non Predicted Class
# Attribution explanations are not limited to the predicted class. Let's test a more complex sentence that contains mixed sentiments.
#
# In the example below we pass `class_name="NEGATIVE"` as an argument indicating we would like the attributions to be explained for the **NEGATIVE** class regardless of what the actual prediction is. Effectively because this is a binary classifier we are getting the inverse attributions.

# %%
cls_explainer = SequenceClassificationExplainer(model, tokenizer)
attributions = cls_explainer("I love you, I like you, I also kinda dislike you", class_name="NEGATIVE")

# %%
print(f'Predicted label {cls_explainer.predicted_class_index} aka {cls_explainer.predicted_class_name} label')
# Out:
# Predicted label 1 aka POSITIVE label

# %% [markdown]
# In this case, `predicted_class_name` still returns a prediction of the **POSITIVE** class, because the model has generated the same prediction but nonetheless we are interested in looking at the attributions for the negative class regardless of the predicted result.

# %%
_ = cls_explainer.visualize()
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>POSITIVE (0.00)</b></text></td><td><text style="padding-right:2em"><b>NEGATIVE</b></text></td><td><text style="padding-right:2em"><b>-1.63</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(0, 75%, 90%); opacity:1.0;                     line-height:1.75"><font color="black"> i                    </font></mark><mark style="background-color: hsl(0, 75%, 70%); opacity:1.0;                     line-height:1.75"><font color="black"> love                    </font></mark><mark style="background-color: hsl(0, 75%, 84%); opacity:1.0;                     line-height:1.75"><font color="black"> you                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ,                    </font></mark><mark style="background-color: hsl(0, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> i                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> like                    </font></mark><mark style="background-color: hsl(0, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> you                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ,                    </font></mark><mark style="background-color: hsl(0, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> i                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> also                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> kinda                    </font></mark><mark style="background-color: hsl(120, 75%, 84%); opacity:1.0;                     line-height:1.75"><font color="black"> dislike                    </font></mark><mark style="background-color: hsl(0, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> you                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [SEP]                    </font></mark></td><tr></table>

# %% [markdown]
# But when we visualize the attributions we can see that the words "*...kinda dislike*" are contributing to a prediction of the "NEGATIVE" class.
#
# Getting attributions for different classes is particularly insightful for multiclass problems as it allows you to inspect model predictions for a number of different classes and sanity-check that the model is "looking" at the right things.

# %% [markdown]
# ## MultiLabel Classification explainer (gradient-based approach)

# %% [markdown]
# Let's download a model for sentiment classification. Possible sentiment are:
# - sadness
# - joy
# - love
# - anger
# - fear
# - surprise

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer
from transformers_interpret import MultiLabelClassificationExplainer

tokenizer = AutoTokenizer.from_pretrained("nateraw/bert-base-uncased-emotion", use_fast=True)
model = AutoModelForSequenceClassification.from_pretrained("nateraw/bert-base-uncased-emotion").cuda()

cls_explainer = MultiLabelClassificationExplainer(model, tokenizer)

word_attributions = cls_explainer("There were many aspects of the film I liked, but it was frightening and gross in parts. My parents hated it.")

_ = cls_explainer.visualize()
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>n/a</b></text></td><td><text style="padding-right:2em"><b> (0.69)</b></text></td><td><text style="padding-right:2em"><b>sadness</b></text></td><td><text style="padding-right:2em"><b>-0.04</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> there                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> were                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> many                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> aspects                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> of                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> film                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> i                    </font></mark><mark style="background-color: hsl(0, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> liked                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ,                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> but                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> it                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> was                    </font></mark><mark style="background-color: hsl(0, 75%, 82%); opacity:1.0;                     line-height:1.75"><font color="black"> frightening                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> and                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> gross                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> in                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-hei ...

# %%
word_attributions = cls_explainer("Sunny summer mornings are really beautiful!")
_ = cls_explainer.visualize()
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>n/a</b></text></td><td><text style="padding-right:2em"><b> (0.17)</b></text></td><td><text style="padding-right:2em"><b>sadness</b></text></td><td><text style="padding-right:2em"><b>-1.59</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(0, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> sunny                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> summer                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> mornings                    </font></mark><mark style="background-color: hsl(0, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> are                    </font></mark><mark style="background-color: hsl(0, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> really                    </font></mark><mark style="background-color: hsl(0, 75%, 63%); opacity:1.0;                     line-height:1.75"><font color="black"> beautiful                    </font></mark><mark style="background-color: hsl(0, 75%, 90%); opacity:1.0;                     line-height:1.75"><font color="black"> !                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [SEP]                    </font></mark></td><tr><tr><td><text style="padding-right:2em"><b>n/a</b></text></td><td><text style="padding-right:2em"><b> (1.00)</b></text></td><td><text style="padding-right:2em"><b>joy</b></text></td><td><text style="padding-right:2em"><b>1.72</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> sunny                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> summer                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> mornings                    </font></mark><mark style="background-color: hsl(120, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> are                    </font></mark><mark style="background-color: hsl(120, 75%, 91%); opacity:1.0;                     line-height:1.75"><font color="black"> really                    </font></mark><mark style="background-color: hsl(120, 75%, 63%); opacity:1.0;                     line-height:1.75"><font color="black"> beautiful                    </font></mark><mark style="background-color: hsl(120, 75%, 71%); opacity:1.0;                     line-height:1.75"><font color="black"> !               ...

# %% [markdown]
# ## MultiLabel Classification explainer (SHAP-based approach)

# %%
import shap
import transformers

# build a pipeline object to do predictions
pred = transformers.pipeline(
    "text-classification",
    model=model,
    tokenizer=tokenizer,
    device=0,
    return_all_scores=True,
)

explainer = shap.Explainer(pred)
# Out:
# Device set to use cuda:0

# %% [markdown]
# In the plots below, when you hover your mouse over an output class you get the explanation for that output class. When you click an output class name then that class remains the focus of the explanation visualization until you click another class.
#
# The base value is what the model outputs when the entire input text is masked. The SHAP values **explain in an addive way how the impact of unmasking each word changes the model output** from the base value (where the entire input is masked) to the final prediction value.

# %%
shap_values = explainer([
    "I love you, I like you",
    "Sunny summer mornings are really beautiful!",
    "I would like to go to the sea but I am too far away to go",
])
shap.plots.text(shap_values)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_dyqfimdiqtvxrbfrljum = '_tp_dyqfimdiqtvxrbfrljum_output_0';
#     document._zoom_dyqfimdiqtvxrbfrljum = undefined;
#     function _output_onclick_dyqfimdiqtvxrbfrljum(i) {
#         var next_id = undefined;
#
#         if (document._zoom_dyqfimdiqtvxrbfrljum !== undefined) {
#             document.getElementById(document._zoom_dyqfimdiqtvxrbfrljum+ '_zoom').style.display = 'none';
#
#             if (document._zoom_dyqfimdiqtvxrbfrljum === '_tp_dyqfimdiqtvxrbfrljum_output_' + i) {
#                 document.getElementById(document._zoom_dyqfimdiqtvxrbfrljum).style.display = 'block';
#                 document.getElementById(document._zoom_dyqfimdiqtvxrbfrljum+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_dyqfimdiqtvxrbfrljum).style.display = 'none';
#                 document.getElementById(document._zoom_dyqfimdiqtvxrbfrljum+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_dyqfimdiqtvxrbfrljum !== '_tp_dyqfimdiqtvxrbfrljum_output_' + i) {
#             next_id = '_tp_dyqfimdiqtvxrbfrljum_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_dyqfimdiqtvxrbfrljum = next_id;
#     }
#     function _output_onmouseover_dyqfimdiqtvxrbfrljum(i, el) {
#         if (document._zoom_dyqfimdiqtvxrbfrljum !== undefined) { return; }
#         if (document._hover_dyqfimdiqtvxrbfrljum !== undefined) {
#             document.getElementById(document._hover_dyqfimdiqtvxrbfrljum + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_dyqfimdiqtvxrbfrljum).style.display = 'none';
#         }
#         document.getElementById('_tp_dyqfimdiqtvxrbfrljum_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_dyqfimdiqtvxrbfrljum = '_tp_dyqfimdiqtvxrbfrljum_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 0.00677361853832443); border-radius: 3px; padding: 0px" id="_tp_dyqfimdiqtvxrbfrljum_output_0_name"
#     onclick="_output_onclick_dyqfimdiqtvxrbfrljum(0)"
#     onmouseover="_output_onmouseover_dyqfimdiqtvxrbfrljum(0, this);">sadness</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.4560903149138443); border-radius: 3px; padding: 0px" id="_tp_dyqfimdiqtvxrbfrljum_output_1_name"
#     onclick="_output_onclick_dyqfimdiqtvxrbfrljum(1)"
#     onmouseover="_output_onmouseover_dyqfimdiqtvxrbfrljum(1, this);">joy</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_dyqfimdiqtvxrbfrljum_output_2_name"
#     onclick="_output_onclick_dyqfimdiqtvxrbfrljum(2)"
#     onmouseover="_output_onmouseover_dyqfimdiqtvxrbfrljum(2, this);">love</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.00677361853832443); border-radius: 3px; padding: 0px" id="_tp_dyqfimdiqtvxrbfrljum_output_3_name"
#     onclick="_output_onclick_dyqfimdiqtvxrbfrljum(3)"
#     onmouseover="_output_onmouseover_dyqfimdiqtvxrbfrljum(3, this);">anger</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_dyqfimdiqtvxrbfrljum_output_4_name"
#     onclick="_output_onclick_dyqfimdiqtvxrbfrljum(4)"
#     onmouseover="_output_onmouseover_dyqfimdiqtvxrbfrljum(4, this);">fear</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_dyqfimdiqtvxrbfrljum_output_5_name"
#     onclick="_output_onclick_dyqfimdiqtvxrbfrljum(5)"
#     onmouseover="_output_onmouseover_dyqfimdiqtvxrbfrljum(5, this);">surprise</div><br><br><div id='_tp_dyqfimdiqtvxrbfrljum_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="51.06565810765512%" y1="33" x2="51.06565810765512%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.06565810765512%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="33.79354705203086%" y1="33" x2="33.79354705203086%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="33.79354705203086%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="16.521435996406602%" y1="33" x2="16.521435996406602%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="16.521435996406602%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="68.33776916327938%" y1="33" x2="68.33776916327938%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="68.33776916327938%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="85.60988021890363%" y1="33" x2="85.60988021890363%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="85.60988021890363%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="20.28617470691652%" y1="33" x2="20.28617470691652%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="20.28617470691652%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.143593</text><text x="20.28617470691652%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.143593</text><text x="20.28617470691652%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="8.348480820380995%" y1="33" x2="8.348480820380995%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="8.348480820380995%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.00536241</text><text x="8.348480820380995%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.00536241</text><text x="8.348480820380995%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">sadness</tspan>(inputs)</text><rect x="8.348480820380995%" width="0.0%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><rect transform="translate(-8,0)" x="8.348480820380995%" y="40" width="8" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792)"/><g transform="translate(-11.5,0)">  <svg x="8.348480820380995%" y="40" height="18" overflow="visible" width="30">    <path d="M 10 -9 l 6 18 L 10 25 L 0 25 L 0 -9" fill="#ffffff" style="stroke:rgb(255,255,255);stroke-width:2" />  </svg></g><rect x="8.348480820380995%" width="11.937693886535524%" y="40" height="18" style="fill:rgb(0.0, 138.56128015770727, 250.76166088685727); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="8.348480820380995%" x2="11.078511871901412%" y1="

# %%
shap.plots.bar(shap_values[:, :, "joy"].mean(0))

# %% [markdown]
# ## Token classification (NER) explainer (gradient-based)
#
# Let's start by initializing a transformers' Token Classfication model and tokenizer, and running it through the `TokenClassificationExplainer`.
#
# For this example we are using `dslim/bert-base-NER`, a bert model finetuned on the CoNLL-2003 **Named Entity Recognition** dataset.

# %%
from transformers import AutoModelForTokenClassification, AutoTokenizer
from transformers_interpret import TokenClassificationExplainer

# model for [location, person] recognition
model = AutoModelForTokenClassification.from_pretrained('dslim/bert-base-NER')
tokenizer = AutoTokenizer.from_pretrained('dslim/bert-base-NER')

ner_explainer = TokenClassificationExplainer(
    model,
    tokenizer,
)

sample_text = "We visited Paris last weekend, where Emmanuel Abc lives."

word_attributions = ner_explainer(
    sample_text,
    ignored_labels=['O']
)
# Out:
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
_ = ner_explainer.visualize()
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>B-LOC</b></text></td><td><text style="padding-right:2em"><b>B-LOC (1.00)</b></text></td><td><text style="padding-right:2em"><b>Paris</b></text></td><td><text style="padding-right:2em"><b>0.91</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> We                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> visited                    </font></mark><mark style="background-color: hsl(120, 75%, 51%); opacity:1.0;                     line-height:1.75"><font color="black"> Paris                    </font></mark><mark style="background-color: hsl(0, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> last                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> weekend                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ,                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> where                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> Emmanuel                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> A                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##b                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##c                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> lives                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> .                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [SEP]                    </font></mark></td><tr><tr><td><text style="padding-right:2em"><b>B-PER</b></text></td><td><text style="padding-right:2em"><b>B-PER (1.00)</b></text></td><td><text style="padding-right:2em"><b>Emmanuel</b></text></td><td><text style="padding-right:2em"><b>1.13</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(0, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> We          ...

# %% [markdown]
# # Explainability in Generative transformers models
#
# Of course, the various explainability techniques can also be applied to generative models, which have the task of generating text from a context (or prompt).
#
# The operation is quite similar, but in this case, **each generated token represents a 'label'** that can be analysed.
# - Why was this particular token generated?
# - What was the model based on to generate this token?

# %% [markdown]
# Il parametro n_steps è usato nella tecnica di Integrated Gradients per determinare il numero di passi discretizzati lungo il percorso di interpolazione tra il baseline (ovvero l'input "mascherato" o di riferimento) e l'input effettivo. In altre parole:
#
# Perché serve: Integrated Gradients calcola l'attribuzione di ciascuna parte dell'input (ad esempio, ogni parola o token) stimando l'integrale dei gradienti lungo una traiettoria che connette il baseline all'input reale.
#
# Cosa fa n_steps: Specifica quanti punti intermedi (o passi) verranno utilizzati per approssimare quell'integrale. Più alto è il numero di passi, migliore (e più preciso) sarà l'approssimazione, sebbene richieda più tempo di calcolo.
#
# Nel codice che hai mostrato, impostando n_steps=500 il modello calcola le Integrated Gradients con 500 incrementi lungo il percorso dalla situazione di baseline a quella dell'input, ottenendo così una stima più fine delle contribuzioni di ciascun token

# %%
import inseq

model = inseq.load_model(
    "gpt2",
    "integrated_gradients",     # we can select different attribution techiniques such us input_x_gradient, integrated_gradients, gradient_shap, lime, ...
)
model.attribute(
    "Hello ladies and",
    generation_args={"max_new_tokens": 9},
    n_steps=500,
    internal_batch_size=50
).show()
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# The following generation flags are not valid and may be ignored: ['output_attentions']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['output_attentions']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# `torch.nn.functional.scaled_dot_product_attention` does not support `output_attentions=True`. Falling back to eager attention. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.
# Attributing with integrated_gradients...: 100%|██████████| 12/12 [00:07<00:00,  1.21it/s]
# <br/><b>0th instance:</b><br/>
# <html>
# <div id="pgnxkwmunflffdzngcmz_viz_container">
#     <div id="pgnxkwmunflffdzngcmz_content" style="padding:15px;border-style:solid;margin:5px;">
#         <div id = "pgnxkwmunflffdzngcmz_saliency_plot_container" class="pgnxkwmunflffdzngcmz_viz_container" style="display:block">
#
# <div id="eryymwxfeuvlduzytkbm_saliency_plot" class="eryymwxfeuvlduzytkbm_viz_content">
#     <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#         <span style="font-size: 20px;">Target Saliency Heatmap</span>
#         <br>
#         x: Generated tokens, y: Attributed tokens
#     </div>
#
# <table border="1" cellpadding="5" cellspacing="5"
#     style="overflow-x:scroll;display:block;">
#     <tr><th></th>
# <th>Ġgentlemen</th><th>,</th><th>ĠI</th><th>Ġam</th><th>Ġa</th><th>Ġmember</th><th>Ġof</th><th>Ġthe</th><th>ĠBoard</th></tr><tr><th>Hello</th><th style="background:rgba(255.0, 13.0, 87.0, 0.4797385620915033)">0.244</th><th style="background:rgba(255.0, 13.0, 87.0, 0.32208358090711037)">0.163</th><th style="background:rgba(255.0, 13.0, 87.0, 0.2590215884333532)">0.133</th><th style="background:rgba(255.0, 13.0, 87.0, 0.4718558130322837)">0.241</th><th style="background:rgba(255.0, 13.0, 87.0, 0.13289760348583876)">0.068</th><th style="background:rgba(255.0, 13.0, 87.0, 0.3693800752624282)">0.191</th><th style="background:rgba(255.0, 13.0, 87.0, 0.14866310160427795)">0.078</th><th style="background:rgba(255.0, 13.0, 87.0, 0.13289760348583876)">0.07</th><th style="background:rgba(255.0, 13.0, 87.0, 0.29843533372945136)">0.152</th></tr><tr><th>Ġladies</th><th style="background:rgba(255.0, 13.0, 87.0, 0.9369380075262429)">0.477</th><th style="background:rgba(255.0, 13.0, 87.0, 0.3142008318478907)">0.161</th><th style="background:rgba(255.0, 13.0, 87.0, 0.3693800752624282)">0.189</th><th style="background:rgba(255.0, 13.0, 87.0, 0.49550406020994264)">0.251</th><th style="background:rgba(255.0, 13.0, 87.0, 0.14866310160427795)">0.08</th><th style="background:rgba(255.0, 13.0, 87.0, 0.44032481679540497)">0.225</th><th style="background:rgba(255.0, 13.0, 87.0, 0.15654585066349747)">0.08</th><th style="background:rgba(255.0, 13.0, 87.0, 0.10136660724896006)">0.054</th><th style="background:rgba(255.0, 13.0, 87.0, 0.29055258467023165)">0.15</th></tr><tr><th>Ġand</th><th style="background:rgba(255.0, 13.0, 87.0, 0.55068330362448)">0.279</th><th style="background:rgba(255.0, 13.0, 87.0, 0.5979797979797981)">0.304</th><th style="background:rgba(255.0, 13.0, 87.0, 0.4245593186769657)">0.216</th><th style="background:rgba(255.0, 13.0, 87.0, 0.13289760348583876)">0.071</th><th style="background:rgba(255.0, 13.0, 87.0, 0.5270350564468211)">0.268</th><th style="background:rgba(255.0, 13.0, 87.0, 0.14866310160427795)">0.079</th><th style="background:rgba(255.0, 13.0, 87.0, 0.08560110913052081)">0.045</th><th style="background:rgba(255.0, 13.0, 87.0, 0.3693800752624282)">0.187</th><th style="background:rgba(255.0, 13.0, 87.0, 0.10924935630817992)">0.056</th></tr><tr><th>Ġgentlemen</th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(255.0, 13.0, 87.0, 0.7319865319865321)">0.372</th><th style="background:rgba(255.0, 13.0, 87.0, 0.4087938205585263)">0.207</th><th style="background:rgba(255.0, 13.0, 87.0, 0.48762131115072294)">0.247</th><th style="background:rgba(255.0, 13.0, 87.0, 0.14866310160427795)">0.079</th><th style="background:rgba(255.0, 13.0, 87.0, 0.44820756585462457)">0.228</th><th style="background:rgba(255.0, 13.0, 87.0, 0.18019409784115661)">0.095</th><th style="background:rgba(255.0, 13.0, 87.0, 0.15654585066349747)">0.083</th><th style="background:rgba(255.0, 13.0, 87.0, 0.4009110714993067)">0.205</th></tr><tr><th>,</th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(255.0, 13.0, 87.0, 0.5033868092691621)">0.255</th><th style="background:rgba(255.0, 13.0, 87.0, 0.12501485442661908)">0.066</th><th style="background:rgba(255.0, 13.0, 87.0, 0.4009110714993067)">0.205</th><th style="background:rgba(255.0, 13.0, 87.0, 0.13289760348583876)">0.071</th><th style="background:rgba(255.0, 13.0, 87.0, 0.07771836007130124)">0.043</th><th style="background:rgba(255.0, 13.0, 87.0, 0.3299663299663301)">0.169</th><th style="background:rgba(255.0, 13.0, 87.0, 0.06983561101208159)">0.039</th></tr><tr><th>ĠI</th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(255.0, 13.0, 87.0, 0.24325609031491383)">0.124</th><th style="background:rgba(255.0, 13.0, 87.0, 0.14866310160427795)">0.076</th><th style="backgro ...

# %% [markdown]
# ### Machine Translation task

# %%
import inseq

# Load the model Helsinki-NLP/opus-mt-en-fr (6-layer encoder-decoder transformer) from the
# Huggingface Hub and hook it with the Input X Gradient feature attribution method
model = inseq.load_model("Helsinki-NLP/opus-mt-en-it", "input_x_gradient")

# Generate the translation for input_texts and attribute inputs at every steps of the generation
# attribute_target=True is used to include the target prefix in the attributed inputs (2nd matrix)
# step scores are computed at every step and returned alongsides attribution scores
out = model.attribute(
    input_texts="Hello everyone, hope you're enjoying the lecture!",
    attribute_target=True,
    step_scores=["probability"],
)
# Visualize the attributions and step scores
out.show()
# Out:
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/343M [00:00<?, ?B/s]
# The following generation flags are not valid and may be ignored: ['output_attentions']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['output_attentions']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/789k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/814k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/343M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.35M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/models/marian/tokenization_marian.py:177: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Attributing with input_x_gradient...:   6%|▌         | 1/18 [00:00<?, ?it/s]Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.58.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# Attributing with input_x_gradient...: 100%|██████████| 18/18 [00:01<00:00, 11.89it/s]
# <br/><b>0th instance:</b><br/>
# <html>
# <div id="cgswiygtsbsesmrqsdrv_viz_container">
#     <div id="cgswiygtsbsesmrqsdrv_content" style="padding:15px;border-style:solid;margin:5px;">
#         <div id = "cgswiygtsbsesmrqsdrv_saliency_plot_container" class="cgswiygtsbsesmrqsdrv_viz_container" style="display:block">
#
# <div id="badvmsphllnjtxfhwaqs_saliency_plot" class="badvmsphllnjtxfhwaqs_viz_content">
#     <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#         <span style="font-size: 20px;">Source Saliency Heatmap</span>
#         <br>
#         x: Generated tokens, y: Attributed tokens
#     </div>
#
# <table border="1" cellpadding="5" cellspacing="5"
#     style="overflow-x:scroll;display:block;">
#     <tr><th></th>
# <th>▁Ci</th><th>a</th><th>o</th><th>▁a</th><th>▁tutti</th><th>,</th><th>▁spero</th><th>▁vi</th><th>▁stia</th><th>te</th><th>▁gode</th><th>ndo</th><th>▁la</th><th>▁le</th><th>zione</th><th>!</th><th>&lt;/s&gt;</th></tr><tr><th>▁H</th><th style="background:rgba(255.0, 13.0, 87.0, 0.36149732620320857)">0.134</th><th style="background:rgba(255.0, 13.0, 87.0, 0.2747870865517925)">0.1</th><th style="background:rgba(255.0, 13.0, 87.0, 0.17231134878193693)">0.063</th><th style="background:rgba(255.0, 13.0, 87.0, 0.14078035254505847)">0.052</th><th style="background:rgba(255.0, 13.0, 87.0, 0.12501485442661908)">0.048</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1880768469003763)">0.07</th><th style="background:rgba(255.0, 13.0, 87.0, 0.10136660724896006)">0.038</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1171321053673995)">0.044</th><th style="background:rgba(255.0, 13.0, 87.0, 0.13289760348583876)">0.05</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.018</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.009</th><th style="background:rgba(255.0, 13.0, 87.0, 0.030421865715983164)">0.013</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.007</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.005</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.003</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.02</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.006</th></tr><tr><th>ello</th><th style="background:rgba(255.0, 13.0, 87.0, 0.5033868092691621)">0.183</th><th style="background:rgba(255.0, 13.0, 87.0, 0.41667656961774624)">0.152</th><th style="background:rgba(255.0, 13.0, 87.0, 0.219607843137255)">0.082</th><th style="background:rgba(255.0, 13.0, 87.0, 0.2511388393741335)">0.092</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1880768469003763)">0.07</th><th style="background:rgba(255.0, 13.0, 87.0, 0.219607843137255)">0.082</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1171321053673995)">0.045</th><th style="background:rgba(255.0, 13.0, 87.0, 0.14866310160427795)">0.056</th><th style="background:rgba(255.0, 13.0, 87.0, 0.15654585066349747)">0.059</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.018</th><th style="background:rgba(255.0, 13.0, 87.0, 0.02253911665676371)">0.011</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.017</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.008</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.006</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.003</th><th style="background:rgba(255.0, 13.0, 87.0, 0.05407011289364243)">0.023</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.008</th></tr><tr><th>▁everyone</th><th style="background:rgba(255.0, 13.0, 87.0, 0.36149732620320857)">0.134</th><th style="background:rgba(255.0, 13.0, 87.0, 0.33784907902554967)">0.123</th><th style="background:rgba(255.0, 13.0, 87.0, 0.13289760348583876)">0.049</th><th style="background:rgba(255.0, 13.0, 87.0, 0.44032481679540497)">0.163</th><th style="background:rgba(255.0, 13.0, 87.0, 0.39302832244008706)">0.144</th><th style="background:rgba(255.0, 13.0, 87.0, 0.15654585066349747)">0.058</th><th style="background:rgba(255.0, 13.0, 87.0, 0.12501485442661908)">0.047</th><th style="background:rgba(255.0, 13.0, 87.0, 0.10924935630817992)">0.042</th><th style="background:rgba(255.0, 13.0, 87.0, 0.09348385818974037)">0.037</th><th style="background:rgba(255.0, 13.0, 87.0, 0.05407011289364243)">0.02</th><th style="background:rgba(255.0, 13.0, 87.0, 0.030421865715983164)">0.012</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.016</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.008</th><th style="background:rgba(255.0, 13. ...

# %% [markdown]
# In questo contesto, il parametro step_scores=["probability"] indica che, durante il processo di attribuzione (in questo caso con il metodo input_x_gradient), verrà calcolato e riportato ad ogni passo (step) di interpolazione lo score di probabilità del modello.
#
# Calcolo a gradini (steps): Quando utilizzi metodi come input_x_gradient o integrated gradients, l'idea di base è quella di passare gradualmente dal baseline (cioè l'input "mascherato" o di riferimento) all'input effettivo, calcolando in più punti intermedi (i "steps") l'effetto di questa transizione. Ogni step è un punto sul percorso di interpolazione.
#
# Score di probabilità: In ciascun step, oltre che a calcolare l'attribuzione (cioè la sensibilità dell'output rispetto ai singoli token), il modello può anche essere configurato per riportare uno score aggiuntivo: in questo caso, la probabilità di output a quel determinato step. Quindi, "probability" qui si riferisce al fatto che ad ogni intervallo del processo, viene calcolata la probabilità del target (o della classe indicata) così da evidenziare come il valore predetto vari man mano che l'input passa dal baseline all'input finale.
#
# Visualizzazione dei risultati: Utilizzando out.show(), il tool di attribuzione visualizza non solo gli score di attribuzione (cioè quali token hanno avuto maggiore impatto) ma anche la curva o gli step scores relativi alla probabilità. Questo ti permette di vedere visivamente come, andando da input mascherato a input completo, la probabilità del modello cambia, evidenziando il percorso di decisione del modello.

# %%
import inseq

model = inseq.load_model("Helsinki-NLP/opus-mt-en-it", "input_x_gradient")

out = model.attribute(
    input_texts="The doctor was pregnant",
    attribute_target=True,
    step_scores=["probability"],
)
# Visualize the attributions and step scores
out.show()
# Out:
# The following generation flags are not valid and may be ignored: ['output_attentions']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['output_attentions']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Attributing with input_x_gradient...: 100%|██████████| 8/8 [00:00<00:00, 12.72it/s]
# <br/><b>0th instance:</b><br/>
# <html>
# <div id="serteopenitppslnuppm_viz_container">
#     <div id="serteopenitppslnuppm_content" style="padding:15px;border-style:solid;margin:5px;">
#         <div id = "serteopenitppslnuppm_saliency_plot_container" class="serteopenitppslnuppm_viz_container" style="display:block">
#
# <div id="ocujzvtstmrnryinqdgz_saliency_plot" class="ocujzvtstmrnryinqdgz_viz_content">
#     <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#         <span style="font-size: 20px;">Source Saliency Heatmap</span>
#         <br>
#         x: Generated tokens, y: Attributed tokens
#     </div>
#
# <table border="1" cellpadding="5" cellspacing="5"
#     style="overflow-x:scroll;display:block;">
#     <tr><th></th>
# <th>▁Il</th><th>▁dotto</th><th>re</th><th>▁era</th><th>▁incinta</th><th>.</th><th>&lt;/s&gt;</th></tr><tr><th>▁The</th><th style="background:rgba(255.0, 13.0, 87.0, 0.4009110714993067)">0.177</th><th style="background:rgba(255.0, 13.0, 87.0, 0.3851455733808676)">0.172</th><th style="background:rgba(255.0, 13.0, 87.0, 0.18019409784115661)">0.082</th><th style="background:rgba(255.0, 13.0, 87.0, 0.2590215884333532)">0.117</th><th style="background:rgba(255.0, 13.0, 87.0, 0.306318082788671)">0.137</th><th style="background:rgba(255.0, 13.0, 87.0, 0.14866310160427795)">0.068</th><th style="background:rgba(255.0, 13.0, 87.0, 0.22749059219647458)">0.104</th></tr><tr><th>▁doctor</th><th style="background:rgba(255.0, 13.0, 87.0, 0.5270350564468211)">0.235</th><th style="background:rgba(255.0, 13.0, 87.0, 0.55068330362448)">0.245</th><th style="background:rgba(255.0, 13.0, 87.0, 0.3536145771439889)">0.16</th><th style="background:rgba(255.0, 13.0, 87.0, 0.2826698356110118)">0.128</th><th style="background:rgba(255.0, 13.0, 87.0, 0.41667656961774624)">0.187</th><th style="background:rgba(255.0, 13.0, 87.0, 0.219607843137255)">0.1</th><th style="background:rgba(255.0, 13.0, 87.0, 0.2826698356110118)">0.127</th></tr><tr><th>▁was</th><th style="background:rgba(255.0, 13.0, 87.0, 0.3772628243216479)">0.169</th><th style="background:rgba(255.0, 13.0, 87.0, 0.36149732620320857)">0.162</th><th style="background:rgba(255.0, 13.0, 87.0, 0.14078035254505847)">0.064</th><th style="background:rgba(255.0, 13.0, 87.0, 0.306318082788671)">0.136</th><th style="background:rgba(255.0, 13.0, 87.0, 0.29843533372945136)">0.134</th><th style="background:rgba(255.0, 13.0, 87.0, 0.14866310160427795)">0.068</th><th style="background:rgba(255.0, 13.0, 87.0, 0.2117250940780353)">0.097</th></tr><tr><th>▁pregnant</th><th style="background:rgba(255.0, 13.0, 87.0, 0.6610417904535549)">0.292</th><th style="background:rgba(255.0, 13.0, 87.0, 0.6295107942166767)">0.278</th><th style="background:rgba(255.0, 13.0, 87.0, 0.29055258467023165)">0.131</th><th style="background:rgba(255.0, 13.0, 87.0, 0.8108140225787285)">0.358</th><th style="background:rgba(255.0, 13.0, 87.0, 0.7162210338680925)">0.318</th><th style="background:rgba(255.0, 13.0, 87.0, 0.3536145771439889)">0.158</th><th style="background:rgba(255.0, 13.0, 87.0, 0.3851455733808676)">0.171</th></tr><tr><th>&lt;/s&gt;</th><th style="background:rgba(255.0, 13.0, 87.0, 0.2826698356110118)">0.127</th><th style="background:rgba(255.0, 13.0, 87.0, 0.26690433749257286)">0.12</th><th style="background:rgba(255.0, 13.0, 87.0, 0.13289760348583876)">0.06</th><th style="background:rgba(255.0, 13.0, 87.0, 0.2511388393741335)">0.112</th><th style="background:rgba(255.0, 13.0, 87.0, 0.29843533372945136)">0.134</th><th style="background:rgba(255.0, 13.0, 87.0, 0.10924935630817992)">0.049</th><th style="background:rgba(255.0, 13.0, 87.0, 0.13289760348583876)">0.062</th></tr><tr style="outline: thin solid"><th><b>probability</b></th><th><b>0.754</b></th><th>0.432</th><th><b>0.908</b></th><th><b>0.866</b></th><th><b>0.569</b></th><th>0.479</th><th><b>0.842</b></th></table>
# </div>
#
#         </div>
#     </div>
# </div>
# </html>
# <br/><b>0th instance:</b><br/>
# <html>
# <div id="zkzrtyvdwjsqejbkejuv_viz_container">
#     <div id="zkzrtyvdwjsqejbkejuv_content" style="padding:15px;border-style:solid;margin:5px;">
#         <div id = "zkzrtyvdwjsqejbkejuv_saliency_plot_container" class="zkzrtyvdwjsqejbkejuv_viz_container" style="display:block">
#
# <div id="dqjqvwdlqvhflaixvdtw_saliency_plot" class="dqjqvwdlqvhflaixvdtw_viz_content">
#     <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#         <span style="font-size: 20px;">Target Saliency Heatmap</span>
#         <br>
#         x: Generated tokens, y: Attributed tokens
#     </div>
#
# <table border="1" cellpadding="5" cellspacing="5"
#     style="overflow-x:scroll;display:block;">
#     <tr><th></th>
# <th>▁Il</th><th>▁dotto</th><th>re</th><th>▁era</th><th>▁incinta</th><th>.</th><th>&lt;/s&gt;</th></tr><tr><th>&lt;pad&gt;</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th></tr><tr><th>▁Il</th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.024</th><th style="background:rgba(255.0, 13.0, 87.0, 0.12501485442661908)">0.059</th><th style="background:rgba(255.0, 13.0, 87.0, 0.09348385818974037)">0.043</th><th style="background:rgba(255.0, 13.0, 87.0, 0.02253911665676371)">0.013</th><th style="background:rgba(255.0, 13.0, 87.0, 0.26690433749257286)">0.119</th><th style="background:rgba(255.0, 13.0, 87.0, 0.06195286195286207)">0.028</th></tr><tr><th>▁dotto</th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(255.0, 13.0, 87.0, 1.0)">0.444</th><th style="background:rgba(255.0, 13.0, 87.0, 0.15654585066349747)">0.07</th><th style="background:rgba(255.0, 13.0, 87.0, 0.06983561101208159)">0.033</th><th style="background:rgba(255.0, 13.0, 87.0, 0.2826698356110118)">0.126</th><th style="background:rgba(255.0, 13.0, 87.0, 0.08560110913052081)">0.039</th></tr><tr><th>re</th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(255.0, 13.0, 87.0, 0.07771836007130124)">0.036</th><th style="background:rgba(255.0, 13.0, 87.0, 0.030421865715983164)">0.016</th><th style="background:rgba(255.0, 13.0, 87.0, 0.10136660724896006)">0.046</th><th style="background:rgba(255.0, 13.0, 87.0, 0.10136660724896006)">0.047</th></tr><tr><th>▁era</th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(255.0, 13.0, 87.0, 0.06195286195286207)">0.029</th><th style="background:rgba(255.0, 13.0, 87.0, 0.15654585066349747)">0.072</th><th style="background:rgba(255.0, 13.0, 87.0, 0.07771836007130124)">0.037</th></tr><tr><th>▁incinta</th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(0.0, 0.0, 0.0, 0.0)"></th><th style="background:rgba(255.0, 13.0, 87.0, 0.43244206773618543)">0.194</th><th style="background:rgba(255.0, 13.0, 87.0, 0.36149732620320857)">0.162</th></tr><tr><th>.</th><th style="background:rgba(0.0, 0.0, 0.0,

# %% [markdown]
# ### Question-Answering task

# %%
import inseq

context = (
    "Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan."
    "Set in a dystopian future where humanity is embroiled in a catastrophic blight and famine, "
    "the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind."
)
# question = "When did the film interstellar come out?"
# question = "Who directed interstellar?"
question = "Where do the astronauts go in the film interstellar?"


context_and_question = context + "\nQuestion: " + question

qa_model = inseq.load_model("consciousAI/question-answering-generative-t5-v1-base-s-q-c", "input_x_gradient")
out = qa_model.attribute(context_and_question, attribute_target=True, step_scores=["probability"])

# Aggregate only source tokens, leave target tokens as they are
out.aggregate("subwords", aggregate_target=False).show()
# Out:
# config.json:   0%|          | 0.00/793 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# The following generation flags are not valid and may be ignored: ['output_attentions']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['output_attentions']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# Attributing with input_x_gradient...:  25%|██▌       | 1/4 [00:00<?, ?it/s]Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# Attributing with input_x_gradient...: 100%|██████████| 4/4 [00:00<00:00,  6.38it/s]
# <br/><b>0th instance:</b><br/>
# <html>
# <div id="bsfycygdrphrlryoipbh_viz_container">
#     <div id="bsfycygdrphrlryoipbh_content" style="padding:15px;border-style:solid;margin:5px;">
#         <div id = "bsfycygdrphrlryoipbh_saliency_plot_container" class="bsfycygdrphrlryoipbh_viz_container" style="display:block">
#
# <div id="pkusdqwhzjcpqolejvon_saliency_plot" class="pkusdqwhzjcpqolejvon_viz_content">
#     <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#         <span style="font-size: 20px;">Source Saliency Heatmap</span>
#         <br>
#         x: Generated tokens, y: Attributed tokens
#     </div>
#
# <table border="1" cellpadding="5" cellspacing="5"
#     style="overflow-x:scroll;display:block;">
#     <tr><th></th>
# <th>▁near</th><th>▁Saturn</th><th>&lt;/s&gt;</th></tr><tr><th>▁Interstellar</th><th style="background:rgba(255.0, 13.0, 87.0, 0.08560110913052081)">0.02</th><th style="background:rgba(255.0, 13.0, 87.0, 0.09348385818974037)">0.02</th><th style="background:rgba(255.0, 13.0, 87.0, 0.15654585066349747)">0.035</th></tr><tr><th>▁is</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.005</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.004</th><th style="background:rgba(255.0, 13.0, 87.0, 0.030421865715983164)">0.007</th></tr><tr><th>▁a</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.004</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.003</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.005</th></tr><tr><th>▁2014</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.01</th><th style="background:rgba(255.0, 13.0, 87.0, 0.02253911665676371)">0.006</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.009</th></tr><tr><th>▁epic</th><th style="background:rgba(255.0, 13.0, 87.0, 0.02253911665676371)">0.006</th><th style="background:rgba(255.0, 13.0, 87.0, 0.02253911665676371)">0.006</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.009</th></tr><tr><th>▁science</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.004</th><th style="background:rgba(255.0, 13.0, 87.0, 0.02253911665676371)">0.006</th><th style="background:rgba(255.0, 13.0, 87.0, 0.030421865715983164)">0.007</th></tr><tr><th>▁fiction</th><th style="background:rgba(255.0, 13.0, 87.0, 0.02253911665676371)">0.006</th><th style="background:rgba(255.0, 13.0, 87.0, 0.030421865715983164)">0.007</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.01</th></tr><tr><th>▁film</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.008</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.009</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.01</th></tr><tr><th>▁co-written,</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.004</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.004</th><th style="background:rgba(255.0, 13.0, 87.0, 0.030421865715983164)">0.008</th></tr><tr><th>▁directed,</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.003</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.003</th><th style="background:rgba(255.0, 13.0, 87.0, 0.02253911665676371)">0.006</th></tr><tr><th>▁and</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.002</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.003</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.003</th></tr><tr><th>▁produced</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.003</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.003</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.005</th></tr><tr><th>▁by</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.002</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.003</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.003</th></tr><tr><th>▁Christopher</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.005</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.004</th><th style="background:rgba(255.0, 13.0, 87.0, 0.02253911665676371)">0.006</th></tr><tr><th>▁Nolan.Set</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.009</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.009</th><th style="background:rgba(255.0, 13.0, 87.0, 0.13289760348583876)">0.03</th></tr><tr><th>▁in</th><th style="background:rgba(2 ...

# %% [markdown]
# Try yourself to challenge the model so that it errs in response:
# - Does the way of asking the question and the terms used challenge the model?
# - Is negation relevant in producing the correct answer in open question answering models like the one we used in the previous example?

# %%
# !pip uninstall -y numpy transformers transformers-interpret captum inseq bitsandbytes shap accelerate
# !pip install --no-cache-dir numpy==1.26.4
# !pip install --no-cache-dir bitsandbytes accelerate shap
# !pip install --no-cache-dir transformers==4.41.1  # o una versione compatibile nota
# !pip install --no-cache-dir transformers-interpret
# !pip install --no-cache-dir captum
# !pip install --no-cache-dir inseq
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Found existing installation: transformers 4.52.4
# Uninstalling transformers-4.52.4:
#   Successfully uninstalled transformers-4.52.4
# Found existing installation: transformers-interpret 0.10.0
# Uninstalling transformers-interpret-0.10.0:
#   Successfully uninstalled transformers-interpret-0.10.0
# Found existing installation: captum 0.8.0
# Uninstalling captum-0.8.0:
#   Successfully uninstalled captum-0.8.0
# Found existing installation: inseq 0.6.0
# Uninstalling inseq-0.6.0:
#   Successfully uninstalled inseq-0.6.0
# Found existing installation: bitsandbytes 0.46.0
# Uninstalling bitsandbytes-0.46.0:
#   Successfully uninstalled bitsandbytes-0.46.0
# Found existing installation: shap 0.47.2
# Uninstalling shap-0.47.2:
#   Successfully uninstalled shap-0.47.2
# Found existing installation: accelerate 1.7.0
# Uninstalling accelerate-1.7.0:
#   Successfully uninstalled accelerate-1.7.0
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 91.0 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 167.8 MB/s eta 0:00:00
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# peft 0.15.2 requires accelerate>=0.21.0, which is not installed.
# peft 0.15.2 requires transformers, which is not installed.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, which is not installed.
# blis 1.0.2 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# thinc 9.1.1 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# torchvision 0.21.0+cu124 requires torch==2.6.0, but you have torch 2.7.1 which is incompatible.
# tensorflow 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.31.1 which is incompatible.
# bigframes 2.5.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# spacy 3.8.7 requires thinc<8.4.0,>=8.3.4, but you have thinc 9.1.1 which is incompatible.
# fastai 2.7.19 requires torch<2.7,>=1.10, but you have torch 2.7.1 which is incompatible.
# ydf 0.12.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 6.31.1 which is incompatible.
# Successfully installed numpy-1.26.4
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Collecting accelerate
#   Downloading accelerate-1.7.0-py3-none-any.whl.metadata (19 kB)
# Collecting shap
#   Downloading shap-0.47.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Requirement already satisfied: torch<3,>=2.2 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.7.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.32.6)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from shap) (1.15.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.11/dist-packages (from shap) (4.67.1)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.11/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.11/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from shap) (3.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from shap) (4.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2025.5.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (1.1.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/dist-packages (from triton==3.3.1->torch<3,>=2.2->bitsandbytes) (80.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.13.3->torch<3,>=2.2->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.2->bitsandbytes) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2025.4.26)
# Downloading bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 177.1 MB/s eta 0:00:00
# Downloading accelerate-1.7.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.1/362.1 kB 395.3 MB/s eta 0:00:00
# Downloading shap-0.47.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 253.9 MB/s eta 0:00:00
# Installing collected packages: shap, bitsandbytes, accelerate
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# peft 0.15.2 requires transformers, which is not installed.
# Successfully installed accelerate-1.7.0 bitsandbytes-0.46.0 shap-0.47.2
# Collecting transformers==4.41.1
#   Downloading transformers-4.41.1-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 18.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.1) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.1) (0.32.6)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.1) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.1) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.1) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.1) (2.32.4)
# Collecting tokenizers<0.20,>=0.19 (from transformers==4.41.1)
#   Downloading tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.1) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.1) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.1) (2025.5.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.1) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.1) (1.1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.41.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.41.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.41.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.41.1) (2025.4.26)
# Downloading transformers-4.41.1-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 55.0 MB/s eta 0:00:00
# Downloading tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 219.0 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
# Successfully installed tokenizers-0.19.1 transformers-4.41.1
# Collecting transformers-interpret
#   Downloading transformers_interpret-0.10.0-py3-none-any.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 29.7 MB/s eta 0:00:00
# Collecting captum>=0.3.1 (from transformers-interpret)
#   Downloading captum-0.8.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: ipython<8.0.0,>=7.31.1 in /usr/local/lib/python3.11/dist-packages (from transformers-interpret) (7.34.0)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from transformers-interpret) (4.41.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from captum>=0.3.1->transformers-interpret) (3.10.3)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.11/dist-packages (from captum>=0.3.1->transformers-interpret) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from captum>=0.3.1->transformers-interpret) (25.0)
# Requirement already satisfied: torch>=1.10 in /usr/local/lib/python3.11/dist-packages (from captum>=0.3.1->transformers-interpret) (2.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from captum>=0.3.1->transformers-interpret) (4.67.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (80.9.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython<8.0.0,>=7.31.1->transformers-interpret) (4.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->transformers-interpret) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->transformers-interpret) (0.32.6)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->transformers-interpret) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->transformers-interpret) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->transformers-interpret) (2.32.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->transformers-interpret) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->transformers-interpret) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers>=3.0.0->transformers-interpret) (2025.5.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers>=3.0.0->transformers-interpret) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers>=3.0.0->transformers-interpret) (1.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython<8.0.0,>=7.31.1->transformers-interpret) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython<8.0.0,>=7.31.1->transformers-interpret) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0.0,>=7.31.1->transformers-interpret) (0.2.13)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum>=0.3.1->transformers-interpret) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum>=0.3.1->transformers-interpret) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum>=0.3.1->transformers-interpret) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum>=0.3.1->transformers-interpret) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum>=0.3.1->transformers-interpret) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum>=0.3.1->transformers-interpret) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum>=0.3.1->transformers-interpret) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum>=0.3.1->transformers-interpret) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum>=0.3.1->transformers-interpret) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum>=0.3.1->transformers-interpret) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum>=0.3.1->transformers-interpret) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum>=0.3.1->transformers-interpret) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum>=0.3.1->transformers-interpret) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum>=0.3.1->transformers-interpret) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum>=0.3.1->transformers-interpret) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum>=0.3.1->transformers-interpret) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum>=0.3.1->transformers-interpret) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum>=0.3.1->transformers-interpret) (3.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum>=0.3.1->transformers-interpret) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum>=0.3.1->transformers-interpret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum>=0.3.1->transformers-interpret) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum>=0.3.1->transformers-interpret) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum>=0.3.1->transformers-interpret) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum>=0.3.1->transformers-interpret) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum>=0.3.1->transformers-interpret) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=3.0.0->transformers-interpret) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=3.0.0->transformers-interpret) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=3.0.0->transformers-interpret) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=3.0.0->transformers-interpret) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->captum>=0.3.1->transformers-interpret) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.13.3->torch>=1.10->captum>=0.3.1->transformers-interpret) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.10->captum>=0.3.1->transformers-interpret) (3.0.2)
# Downloading transformers_interpret-0.10.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 238.0 MB/s eta 0:00:00
# Downloading captum-0.8.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 103.0 MB/s eta 0:00:00
# Installing collected packages: captum, transformers-interpret
# Successfully installed captum-0.8.0 transformers-interpret-0.10.0
# Requirement already satisfied: captum in /usr/local/lib/python3.11/dist-packages (0.8.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from captum) (3.10.3)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.11/dist-packages (from captum) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from captum) (25.0)
# Requirement already satisfied: torch>=1.10 in /usr/local/lib/python3.11/dist-packages (from captum) (2.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from captum) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (4.14.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/dist-packages (from triton==3.3.1->torch>=1.10->captum) (80.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->captum) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.13.3->torch>=1.10->captum) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.10->captum) (3.0.2)
# Collecting inseq
#   Downloading inseq-0.6.0-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: rich>=10.13.0 in /usr/local/lib/python3.11/dist-packages (from inseq) (14.0.0)
# Requirement already satisfied: transformers>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (4.41.1)
# Requirement already satisfied: protobuf>=3.20.1 in /usr/local/lib/python3.11/dist-packages (from inseq) (6.31.1)
# Requirement already satisfied: captum>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from inseq) (0.8.0)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from inseq) (1.26.4)
# Requirement already satisfied: jaxtyping>=0.2.25 in /usr/local/lib/python3.11/dist-packages (from inseq) (0.3.2)
# Requirement already satisfied: typeguard<=2.13.3 in /usr/local/lib/python3.11/dist-packages (from inseq) (2.13.3)
# Requirement already satisfied: torch>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from inseq) (2.7.1)
# Requirement already satisfied: matplotlib>=3.5.3 in /usr/local/lib/python3.11/dist-packages (from inseq) (3.10.3)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from inseq) (4.67.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from captum>=0.7.0->inseq) (25.0)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from jaxtyping>=0.2.25->inseq) (0.1.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->inseq) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.13.0->inseq) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.13.0->inseq) (2.19.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (4.14.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.1->inseq) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/dist-packages (from triton==3.3.1->torch>=2.1.1->inseq) (80.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (0.32.6)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (2.32.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (0.5.3)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.11/dist-packages (from transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (0.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (1.1.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.13.0->inseq) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.3->inseq) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.13.3->torch>=2.1.1->inseq) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.1.1->inseq) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.22.0->transformers[sentencepiece,tokenizers]>=4.22.0->inseq) (2025.4.26)
# Downloading inseq-0.6.0-py3-none-any.whl (186 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.6/186.6 kB 32.2 MB/s eta 0:00:00
# Installing collected packages: inseq
# Successfully installed inseq-0.6.0

# %% [markdown]
# The model consciousAI/question-answering-generative-t5-v1-base-s-q-c may not be performing well for several reasons, most likely related to domain mismatch, insufficient fine-tuning, or limitations in the prompt structure. While the model is designed for question answering tasks, it may not have been fine-tuned sufficiently on inputs structured in the "context + \nQuestion: + question" format, or on examples involving nuanced language and indirect reasoning, such as identifying implicit punitive aspects from narrative game descriptions.
#
# Moreover, the attribution method used (input_x_gradient) is a gradient-based technique that may sometimes struggle to highlight clear and semantically grounded input-output relationships in generative QA tasks, especially when the model's prediction confidence is low or the input tokens are semantically diffuse.

# %%
import inseq

context = (
    "Elden Ring is an unmissable, must-play, gaming experience with surprises "
    "galore. Elden Ring's engaging combat, mythology and dynamite orchestral soundtrack "
    "goes a long way to overshadow an aggressive open world that punishes exploration from the beaten path."

)
question = "What does Elden Ring punish?" # work well
# question = "How is the soundtrack?" # in this phrase in seems that it took the text after the word
# question = "Is Elden Ring not dynamite?" # not working well with negation

context_and_question = context + "\nQuestion: " + question

qa_model = inseq.load_model("consciousAI/question-answering-generative-t5-v1-base-s-q-c", "input_x_gradient")
out = qa_model.attribute(context_and_question, attribute_target=True, step_scores=["probability"])

# Aggregate only source tokens, leave target tokens as they are
out.aggregate("subwords", aggregate_target=False).show()
# Out:
# Attributing with input_x_gradient...: 100%|██████████| 8/8 [00:01<00:00,  4.81it/s]
# <br/><b>0th instance:</b><br/>
# <html>
# <div id="gysvgwdppuclptbynycy_viz_container">
#     <div id="gysvgwdppuclptbynycy_content" style="padding:15px;border-style:solid;margin:5px;">
#         <div id = "gysvgwdppuclptbynycy_saliency_plot_container" class="gysvgwdppuclptbynycy_viz_container" style="display:block">
#
# <div id="mxzjdowpwfhxsxobdiic_saliency_plot" class="mxzjdowpwfhxsxobdiic_viz_content">
#     <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#         <span style="font-size: 20px;">Source Saliency Heatmap</span>
#         <br>
#         x: Generated tokens, y: Attributed tokens
#     </div>
#
# <table border="1" cellpadding="5" cellspacing="5"
#     style="overflow-x:scroll;display:block;">
#     <tr><th></th>
# <th>▁exploration</th><th>▁from</th><th>▁the</th><th>▁</th><th>beaten</th><th>▁path</th><th>&lt;/s&gt;</th></tr><tr><th>▁Elden</th><th style="background:rgba(255.0, 13.0, 87.0, 0.08560110913052081)">0.02</th><th style="background:rgba(255.0, 13.0, 87.0, 0.06195286195286207)">0.016</th><th style="background:rgba(255.0, 13.0, 87.0, 0.13289760348583876)">0.03</th><th style="background:rgba(255.0, 13.0, 87.0, 0.05407011289364243)">0.013</th><th style="background:rgba(255.0, 13.0, 87.0, 0.030421865715983164)">0.009</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.01</th><th style="background:rgba(255.0, 13.0, 87.0, 0.10924935630817992)">0.026</th></tr><tr><th>▁Ring</th><th style="background:rgba(255.0, 13.0, 87.0, 0.06983561101208159)">0.016</th><th style="background:rgba(255.0, 13.0, 87.0, 0.05407011289364243)">0.014</th><th style="background:rgba(255.0, 13.0, 87.0, 0.08560110913052081)">0.021</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.011</th><th style="background:rgba(255.0, 13.0, 87.0, 0.030421865715983164)">0.007</th><th style="background:rgba(255.0, 13.0, 87.0, 0.030421865715983164)">0.007</th><th style="background:rgba(255.0, 13.0, 87.0, 0.07771836007130124)">0.019</th></tr><tr><th>▁is</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.005</th><th style="background:rgba(255.0, 13.0, 87.0, 0.02253911665676371)">0.006</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.009</th><th style="background:rgba(255.0, 13.0, 87.0, 0.02253911665676371)">0.006</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.003</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.004</th><th style="background:rgba(255.0, 13.0, 87.0, 0.02253911665676371)">0.005</th></tr><tr><th>▁an</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.004</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.003</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.005</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.005</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.002</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.003</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.005</th></tr><tr><th>▁unmissable,</th><th style="background:rgba(255.0, 13.0, 87.0, 0.06195286195286207)">0.015</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.01</th><th style="background:rgba(255.0, 13.0, 87.0, 0.06983561101208159)">0.016</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.009</th><th style="background:rgba(255.0, 13.0, 87.0, 0.02253911665676371)">0.007</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.012</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.012</th></tr><tr><th>▁must-play,</th><th style="background:rgba(255.0, 13.0, 87.0, 0.06195286195286207)">0.015</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.011</th><th style="background:rgba(255.0, 13.0, 87.0, 0.06983561101208159)">0.016</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.012</th><th style="background:rgba(255.0, 13.0, 87.0, 0.030421865715983164)">0.008</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.011</th><th style="background:rgba(255.0, 13.0, 87.0, 0.05407011289364243)">0.013</th></tr><tr><th>▁gaming</th><th style="background:rgba(255.0, 13.0, 87.0, 0.06983561101208159)">0.016</th><th style="background:rgba(255.0, 13.0, 87.0, 0.08560110913052081)">0.02</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.012</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.011</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.012</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03 ...
